# %% [markdown]
# <a href="https://colab.research.google.com/github/Otaboyev0727/Amalyotlar/blob/main/MAlumotlar_bn_ishlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql
import numpy  as np

# %%
# !wget https://github.com/anvarnarz/praktikum_datasets/blob/main/electricity.db
# Out:
# --2022-10-11 18:25:05--  https://github.com/anvarnarz/praktikum_datasets/blob/main/electricity.db
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘electricity.db.2’
#
# electricity.db.2        [ <=>                ] 133.86K  --.-KB/s    in 0.02s
#
# 2022-10-11 18:25:06 (5.69 MB/s) - ‘electricity.db.2’ saved [137071]

# %%
db1=sql.connect('electricity.db')
cursor=db1.cursor()

# %%
cursor.execute('PRAGMA table_info(elect);')
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-12-ad022e7e37ea> in <module>
# ----> 1 cursor.execute('PRAGMA table_info(elect);')
#       2 cursor.fetchall()
#
# DatabaseError: file is not a database

# %%
cursor.execute("Select name FROM sqlite_master WHERE type='table';")
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-11-07da3b3492bb> in <module>
# ----> 1 cursor.execute("Select name FROM sqlite_master WHERE type='table';")
#       2 cursor.fetchall()
#
# DatabaseError: file is not a database

# %%
df=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data_nan.csv",index_col='index')

# %%
len(df)
# Out:
# 61

# %%
df.shape
# Out:
# (61, 10)

# %%
df.isnull().sum()/len(df)*100
# Out:
# index                0.000000
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df.dropna()
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
df.dropna(axis=1)
# Out:
#     index      company   body-style num-of-cylinders
# 0       0  alfa-romero  convertible             four
# 1       1  alfa-romero  convertible             four
# 2       2  alfa-romero    hatchback              six
# 3       3         audi        sedan             four
# 4       4         audi        sedan             five
# ..    ...          ...          ...              ...
# 56     81   volkswagen        sedan             four
# 57     82   volkswagen        sedan             four
# 58     86   volkswagen        sedan             four
# 59     87        volvo        sedan             four
# 60     88        volvo        wagon             four
#
# [61 rows x 4 columns]

# %%
df.dropna(axis=1, thresh=50)
# Out:
#     index      company   body-style num-of-cylinders    price
# 0       0  alfa-romero  convertible             four  13495.0
# 1       1  alfa-romero  convertible             four  16500.0
# 2       2  alfa-romero    hatchback              six  16500.0
# 3       3         audi        sedan             four  13950.0
# 4       4         audi        sedan             five  17450.0
# ..    ...          ...          ...              ...      ...
# 56     81   volkswagen        sedan             four   7975.0
# 57     82   volkswagen        sedan             four   7995.0
# 58     86   volkswagen        sedan             four   9995.0
# 59     87        volvo        sedan             four  12940.0
# 60     88        volvo        wagon             four  13415.0
#
# [61 rows x 5 columns]

# %%
df.dropna(subset=['price']).head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df.fillna(97)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        97.0   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.0   171.7          97
# 58     86   volkswagen        sedan        97.3    97.0         ohc
# 59     87        volvo        sedan       104.3   188.8          97
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four        97.0             21.0  13495.0
# ...

# %%
df.fillna({"horsepower":np.mean(df['horsepower']),"price":np.mean(df['price'])})
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four  108.266667             21.0  13495.0
# ...

# %%
df.fillna(method="ffill")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method="bfill")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        94.5   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   188.8         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four       111.0             21.0  13495.0
# ...

# %%
dfs=df[df['body-style']=='sedan']

# %%
df.fillna(dfs.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible   88.600000   168.8        dohc
# 1       1  alfa-romero  convertible  102.058333   168.8        dohc
# 2       2  alfa-romero    hatchback   94.500000   171.2        ohcv
# 3       3         audi        sedan   99.800000   176.6         ohc
# 4       4         audi        sedan   99.400000   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan   97.300000   171.7         ohc
# 57     82   volkswagen        sedan  102.058333   171.7         NaN
# ...

# %%
df['body-style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
pd.DataFrame(df['company'].unique())
# Out:
#                 0
# 0     alfa-romero
# 1            audi
# 2             bmw
# 3       chevrolet
# 4           dodge
# 5           honda
# 6           isuzu
# 7          jaguar
# 8           mazda
# 9   mercedes-benz
# 10     mitsubishi
# 11         nissan
# 12        porsche
# 13         toyota
# 14     volkswagen
# 15          volvo

# %%
df.set_index('index')
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv",index_col='rank')

# %%
df2.duplicated().sum()
# Out:
# 15

# %%
df2.drop_duplicates()
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df2.drop_duplicates(['country'])
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dict={'two':2,'three':3,'four':4,'five':5,'six':6,'eight':8,'twelve':12}

# %%
df['cylindrs']=df['num-of-cylinders'].map(dict)

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price  cylindrs
# 0              four         NaN             21.0  13495.0         4
# ...

# %%
kurs=11010
df['price_uz']=df['price'].map(lambda x:x*kurs)
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price  cylindrs  \
# 0              four         NaN             21.0  13495.0         4
# ...

# %%
df3=df2.set_index('country')

# %%
df.replace(dict)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#        num-of-cylinders  horsepower  average-mileage    price
# index
# 0                     4         NaN             21.0  13495.0
# ...

# %%
df3.rename(index=str.upper,columns=str.upper)
# Out:
#                      DENSITY   DENSITYMI    POP2021     AREA
# country
# MACAU             21946.4667  56841.3487    658.394       30
# MONACO            19755.5000  51166.7450     39.511        2
# BURUNDI             440.3044   1140.3884  12255.433    27834
# MACAU             21946.4667  56841.3487    658.394       30
# MONACO            19755.5000  51166.7450     39.511        2
# ...                      ...         ...        ...      ...
# NAMIBIA               3.1338      8.1166   2587.344   825615
# WESTERN SAHARA        2.3003      5.9577    611.875   266000
# MONGOLIA              2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS      0.2902      0.7517      3.533    12173
# GREENLAND             0.0263      0.0680     56.877  2166086
#
# [247 rows x 4 columns]

# %%
df3.rename(index={'Macau':"Makau"},columns={"pop2021":"populition"})
# Out:
#                      density   densityMi  populition     area
# country
# Makau             21946.4667  56841.3487     658.394       30
# Monaco            19755.5000  51166.7450      39.511        2
# Burundi             440.3044   1140.3884   12255.433    27834
# Makau             21946.4667  56841.3487     658.394       30
# Monaco            19755.5000  51166.7450      39.511        2
# ...                      ...         ...         ...      ...
# Namibia               3.1338      8.1166    2587.344   825615
# Western Sahara        2.3003      5.9577     611.875   266000
# Mongolia              2.1286      5.5129    3329.289  1564110
# Falkland Islands      0.2902      0.7517       3.533    12173
# Greenland             0.0263      0.0680      56.877  2166086
#
# [247 rows x 4 columns]

# %%
df5=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv",usecols=['country','pop2021','area'],index_col='country')

# %%
df5.head()
# Out:
#             pop2021  area
# country
# Macau       658.394    30
# Monaco       39.511     2
# Singapore  5896.686   710
# Hong Kong  7552.810  1104
# Gibraltar    33.698     6

# %%
bins=[0,1000,2000,5000,10000,15000]

# %%
pd.cut(df5.pop2021,bins).value_counts()
# Out:
# (0, 1000]         72
# (5000, 10000]     31
# (2000, 5000]      27
# (10000, 15000]    18
# (1000, 2000]      10
# Name: pop2021, dtype: int64

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
name=["arzon","o'rtacha","qimmat"]

# %%
pd.cut(df.price,[0,10000,20000,25000],labels=name).value_counts()
# Out:
# arzon       28
# o'rtacha    17
# qimmat       1
# Name: price, dtype: int64

# %%
pd.cut(df.price,5).value_counts()
# Out:
# (5110.751, 13200.8]    32
# (13200.8, 21250.6]     14
# (29300.4, 37350.2]      7
# (37350.2, 45400.0]      3
# (21250.6, 29300.4]      2
# Name: price, dtype: int64

# %%
pd.qcut(df.price,5).value_counts()
# Out:
# (5150.999, 6604.6]    12
# (7959.6, 13589.2]     12
# (23719.2, 45400.0]    12
# (6604.6, 7959.6]      11
# (13589.2, 23719.2]    11
# Name: price, dtype: int64

# %%
df.groupby('company').mean()
# Out:
#                wheel-base      length  horsepower  average-mileage  \
# company
# alfa-romero     91.550000  169.600000  132.500000        21.000000
# audi           101.200000  180.800000  107.333333        20.666667
# bmw            103.880000  184.900000  146.500000        19.500000
# chevrolet       91.450000  151.933333   70.000000        42.500000
# dodge           93.700000  157.300000   68.000000        31.000000
# honda           96.500000  172.250000   88.500000        26.333333
# isuzu           94.500000  163.300000   72.666667        31.000000
# jaguar         113.000000  195.650000  219.000000        14.333333
# mazda           96.050000  163.075000   79.000000        26.333333
# mercedes-benz  114.300000  197.275000  153.500000        18.000000
# mitsubishi      95.433333  167.366667   78.000000        31.000000
# nissan          96.466667  171.350000   82.800000        31.000000
# porsche         93.950000  172.300000  207.000000        17.000000
# ...

# %%
df.groupby(['company','body-style']).max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                            wheel-base  length num-of-cylinders  horsepower  \
# company       body-style
# alfa-romero   convertible        88.6   168.8             four       111.0
#               hatchback          94.5   171.2              six       154.0
# audi          sedan              99.8   177.3             four       110.0
#               wagon             105.8   192.7             five       110.0
# bmw           sedan             110.0   197.0              six       182.0
# chevrolet     hatchback          94.5   155.9            three        70.0
#               sedan               NaN   158.8             four        70.0
# ...

# %%
df.groupby(['company']).agg([min,max,np.mean])
# Out:
#               wheel-base                    length                     \
#                      min    max        mean    min    max        mean
# company
# alfa-romero         88.6   94.5   91.550000  168.8  171.2  169.600000
# audi                99.4  105.8  101.200000  176.6  192.7  180.800000
# bmw                101.2  110.0  103.880000  176.8  197.0  184.900000
# chevrolet           88.4   94.5   91.450000  141.1  158.8  151.933333
# dodge               93.7   93.7   93.700000  157.3  157.3  157.300000
# honda               96.5   96.5   96.500000  169.1  175.4  172.250000
# isuzu               94.5   94.5   94.500000  155.9  170.7  163.300000
# jaguar             113.0  113.0  113.000000  191.7  199.6  195.650000
# mazda               93.1  104.9   96.050000  159.1  175.0  163.075000
# mercedes-benz      110.0  120.9  114.300000  190.9  208.1  197.275000
# mitsubishi          93.7   96.3   95.433333  157.3  172.4  167.366667
# ...

# %%
df6=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/MOCK_USER_DATA.csv",index_col=0)
df6.describe()
# Out:
#                age
# count   100.000000
# mean    145.660000
# std     565.631411
# min     -85.000000
# 25%      22.750000
# 50%      53.500000
# 75%      84.250000
# max    4444.000000

# %%
df6[(df6.age>123)|(df6.age<0)]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 11      Elijah      Heine                eheinea@imdb.com     Bigender   -85
# 19       Luisa  Bradborne            lbradbornei@fema.gov       Female   -75
# 21       Levin     Worner                lwornerk@ihg.com  Genderqueer   -43
# 33    Ebenezer    Greeves           egreevesw@myspace.com         Male   -26
# 38        Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer   -42
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# ...

# %%
df6['age']=df6.age.apply(np.abs, inplace=True)

# %%
df6[df6.age<0].index
# Out:
# Int64Index([], dtype='int64', name='id')

# %%
df6[df6.age>123].index
# Out:
# Int64Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df6.drop([3, 39, 47, 49, 65, 80, 100],inplace=True)

# %%
df6.describe()
# Out:
#               age
# count   93.000000
# mean    52.612903
# std     29.978265
# min      1.000000
# 25%     29.000000
# 50%     52.000000
# 75%     77.000000
# max    100.000000

# %%
df7=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/MOCK_USER_DATA.csv",index_col=0)

# %%
df7.sample(10)
# Out:
#    first_name    last_name                         email       gender  age
# id
# 44     Marice    Champneys    mchampneys17@bigcartel.com     Bigender   49
# 7       Wendy      Popland              wpopland6@cbc.ca  Genderfluid   67
# 20      Arlie      Mintram      amintramj@soundcloud.com     Bigender   41
# 17      Byram  Martynikhin     bmartynikhing@jiathis.com         Male   40
# 73      Liane      Cackett          lcackett20@jigsy.com  Genderqueer   40
# 90  Zachariah        Meins          zmeins2h@weather.com         Male  -69
# 55      Hiram     Bringloe            hbringloe1i@pen.io   Polygender   50
# 5    Mohammed   Habbershon  mhabbershon4@sourceforge.net       Female   48
# 41   Katheryn     Ashleigh        kashleigh14@devhub.com      Agender   36
# 9         Der       Neames      dneames8@ycombinator.com     Bigender   77

# %%
df7.take(np.random.permutation(100))
# Out:
#     first_name   last_name                         email       gender  age
# id
# 15        Suzy     Bortoli           sbortolie@opera.com      Agender  100
# 65      Eloise     Snoddon  esnoddon1s@elegantthemes.com  Genderfluid  332
# 49       Trace    Stockney        tstockney1c@flavors.me       Female  344
# 18     Artemus    Shovelin         ashovelinh@sphinn.com   Non-binary   58
# 33    Ebenezer     Greeves         egreevesw@myspace.com         Male  -26
# ..         ...         ...                           ...          ...  ...
# 81        Alex       Darth    adarth28@ezinearticles.com       Female   98
# 8          Nye   Anthiftle      nanthiftle7@examiner.com      Agender   99
# 100      Mable     Toffano        mtoffano2r@myspace.com     Bigender  233
# 5     Mohammed  Habbershon  mhabbershon4@sourceforge.net       Female   48
# 60   Geraldine      Beddie       gbeddie1n@earthlink.net     Bigender   86
#
# [100 rows x 5 columns]

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Otaboyev0727/datasets/main/melb_data.csv")

# %%
df
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 0        Abbotsford      85 Turner St      2    h  1480000.0      S
# 1        Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford  40 Federation La      3    h   850000.0     PI
# 4        Abbotsford       55a Park St      4    h  1600000.0     VB
# ...             ...               ...    ...  ...        ...    ...
# 12206  Williamstown       87 Pasco St      3    h  1285000.0      S
# 12207       Windsor   201/152 Peel St      2    u   560000.0     PI
# 12208       Wollert   60 Saltlake Bvd      3    h   525300.0      S
# 12209    Yarraville       2 Adeney St      2    h   750000.0     SP
# 12210    Yarraville   54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.BuildingArea.mean()
# Out:
# 144.22205145826868
